# %%
import os
from matplotlib import pyplot as plt

# %%
f = './loss_file.csv'

# %%
def show_figure(loss_num, loss_name, begin_num, end_num):
    plt.figure(figsize=(15, 5))

    plt.subplot(121)
    plt.plot(df[loss_num][:begin_num])
    plt.title('%s loss [:%d]' % (loss_name, begin_num))

    plt.subplot(122)
    plt.plot(df[loss_num][-end_num:])
    plt.title('%s loss [-%d:]' % (loss_name, end_num))

    plt.show()

# %%
def show_figure2():
    plt.figure(figsize=(15, 5))

    plt.subplot(131)
    plt.plot(df[0])
    plt.title('corner loss')

    plt.subplot(132)
    plt.plot(df[1])
    plt.title('icon loss')
    
    plt.subplot(133)
    plt.plot(df[2])
    plt.title('room loss')
             
    plt.show()

# %%
# data augmentation
f = './loss_file.csv'
df = pd.read_csv(f, header=None)
print(df.info())
show_figure2()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335384 entries, 0 to 335383
# Data columns (total 3 columns):
# 0    335384 non-null float64
# 1    335384 non-null float64
# 2    335384 non-null float64
# dtypes: float64(3)
# memory usage: 7.7 MB
# None
